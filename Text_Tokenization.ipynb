# %%
# !pip install spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.8 MB 330.3 kB/s eta 0:00:39
#      --------------------------------------- 0.0/12.8 MB 326.8 kB/s eta 0:00:40
#      --------------------------------------- 0.1/12.8 MB 655.4 kB/s eta 0:00:20
#      --------------------------------------- 0.1/12.8 MB 722.1 kB/s eta 0:00:18
#       -------------------------------------- 0.2/12.8 MB 697.2 kB/s eta 0:00:19
#       -------------------------------------- 0.2/12.8 MB 692.9 kB/s eta 0:00:19
#       -------------------------------------- 0.2/12.8 MB 593.2 kB/s eta 0:00:22
#       -------------------------------------- 0.3/12.8 MB 710.0 kB/s eta 0:00:18
#      - ------------------------------------- 0.3/12.8 MB 838.1 kB/s eta 0:00:15
#      - ------------------------------------- 0.4/12.8 MB 873.3 kB/s eta 0:00:15
#      - ------------------------------------- 0.5/12.8 MB 992.2 kB/s eta 0:00:13
# ...

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp("Hi, this is Mohamed Saadeldin. This is a demo for text tokenization and digitalization. I'm just trying spacy")

# %%
print (len(doc))
# Out:
# 22

# %%
text = doc

# %%
     for token in doc:
        print (token)
# Out:
# Hi
# ,
# this
# is
# Mohamed
# Saadeldin
# .
# This
# is
# a
# demo
# for
# text
# tokenization
# and
# digitalization
# .
# I
# 'm
# just
# trying
# spacy
